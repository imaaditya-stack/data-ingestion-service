# %%
# !uv add pandas
# Out:
# Resolved 179 packages in 0.70ms
# Audited 150 packages in 0.85ms

# %%
import pandas as pd

# %%
df = pd.read_excel("../__data__/products_data.xlsx")

# %%
df.head()
# Out:
#    id     PRODUCT_NAME  PRODUCT_CATEGORY_id  PRODUCT_CATALOGUE_NUMBER  \
# 0   2            Busbx                    5                       NaN
# 1   5  Digital  camera                    5                       NaN
# 2   7       headphones                    5                       NaN
# 3   8       Samsung Tv                    5                       NaN
# 4   9          Cameras                    5                       NaN
#
#    PRODUCT_HSN_NO  PRODUCT_VIDEO_LINK  \
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
#
#                                  PRODUCT_DESCRIPTION  \
# 0                                              Ubwhx
# 1  Digital camera. A digital camera is an electro...
# 2  With Mic:Yes\r\nBEAST Mode: Experience lag-fre...
# 3  Samsung 80 cm (32 Inch) HD Ready LED Smart\n\n...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        111 non-null    int64
#  1   PRODUCT_NAME              111 non-null    object
#  2   PRODUCT_CATEGORY_id       111 non-null    int64
#  3   PRODUCT_CATALOGUE_NUMBER  0 non-null      float64
#  4   PRODUCT_HSN_NO            0 non-null      float64
#  5   PRODUCT_VIDEO_LINK        0 non-null      float64
#  6   PRODUCT_DESCRIPTION       111 non-null    object
#  7   PRODUCT_SPECS_FILE        2 non-null      object
#  8   ACTUAL_FILENAME           0 non-null      float64
#  9   TITLE                     0 non-null      float64
#  10  IS_APPROVED               111 non-null    bool
#  11  IS_REJECTED               111 non-null    bool
#  12  SELLER_id                 111 non-null    int64
# ...

# %%
df.describe()
# Out:
#                id  PRODUCT_CATEGORY_id  PRODUCT_CATALOGUE_NUMBER  \
# count  111.000000           111.000000                       0.0
# mean    59.963964            11.918919                       NaN
# min      2.000000             2.000000                       NaN
# 25%     32.500000             5.000000                       NaN
# 50%     60.000000            15.000000                       NaN
# 75%     87.500000            20.000000                       NaN
# max    115.000000            26.000000                       NaN
# std     32.250138             8.546275                       NaN
#
#        PRODUCT_HSN_NO  PRODUCT_VIDEO_LINK  ACTUAL_FILENAME  TITLE   SELLER_id  \
# count             0.0                 0.0              0.0    0.0  111.000000
# mean              NaN                 NaN              NaN    NaN   21.027027
# min               NaN                 NaN              NaN    NaN    6.000000
# ...

# %%
df.columns
# Out:
# Index(['id', 'PRODUCT_NAME', 'PRODUCT_CATEGORY_id', 'PRODUCT_CATALOGUE_NUMBER',
#        'PRODUCT_HSN_NO', 'PRODUCT_VIDEO_LINK', 'PRODUCT_DESCRIPTION',
#        'PRODUCT_SPECS_FILE', 'ACTUAL_FILENAME', 'TITLE', 'IS_APPROVED',
#        'IS_REJECTED', 'SELLER_id', 'THUMBNAIL_IMAGE', 'MIN_PRICE', 'MAX_PRICE',
#        'STATUS', 'REASON', 'CREATED_AT', 'UPDATED_AT'],
#       dtype='object')

# %%
df[["id", "PRODUCT_NAME", "PRODUCT_CATEGORY_id", "PRODUCT_DESCRIPTION"]].head()
# Out:
#    id     PRODUCT_NAME  PRODUCT_CATEGORY_id  \
# 0   2            Busbx                    5
# 1   5  Digital  camera                    5
# 2   7       headphones                    5
# 3   8       Samsung Tv                    5
# 4   9          Cameras                    5
#
#                                  PRODUCT_DESCRIPTION
# 0                                              Ubwhx
# 1  Digital camera. A digital camera is an electro...
# 2  With Mic:Yes\r\nBEAST Mode: Experience lag-fre...
# 3  Samsung 80 cm (32 Inch) HD Ready LED Smart\n\n...
# 4                                               Teyh
